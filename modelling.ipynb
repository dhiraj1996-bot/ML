# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("C:\\Users\Admin\Downloads\Python_ML_new-master\Python_ML_new-master\house.csv")

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
x=df["sqft_living"]
y=df["price"]

# %%
sns.scatterplot(data=df,x=x,y=y)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.lmplot(data=df,x="sqft_living",y="price")# lmplot shows the regression line as well
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit([x_train],[y_train])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
#lr.fit(x_train,y_train)
#lr_confidence=lr.score(x_test,y_test)
lr.fit(x_train.as_matrix().reshape((-1,1)),y_train)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([277.95630802])

# %%
lr.intercept_
# Out:
# -38275.84686927439

# %%
y_pred=lr.predict(x_test.as_matrix().reshape((-1,1)))
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
y_pred
# Out:
# array([364760.7997624 , 359201.67360197, 389776.86748437, ...,
#        626039.72930294, 901216.47424457, 609084.39451361])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
mse=mean_squared_error(y_pred,y_test)

# %%
mse
# Out:
# 70529881074.04984

# %%
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# 265574.624303697

# %%
mae=mean_absolute_error(y_pred,y_test)

# %%
mae
# Out:
# 174753.50177224696

# %%
r2_score(y_test,y_pred)
# Out:
# 0.49578348819553253
