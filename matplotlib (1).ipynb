# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\Admin\Desktop\ML\Python_ML_new-master\Python_ML_new-master\house.csv")

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
x=["sqft_living"]
y=["sqft_lot"]

# %%
plt.scatter(x=df["sqft_living"],y=df["sqft_lot"])
plt.xlabel("sqft_living")
plt.ylabel("sqft_lot")
plt.title("Housing")
plt.show()

# %%
plt.hist(df["yr_built"])
plt.xlabel("sqft_living")
plt.ylabel("sqft_lot")
plt.title("Housing")
plt.show()

# %%
df["bedrooms"].value_counts().plot(kind="bar")
plt.title("Housing")
plt.show()

# %%
plt.scatter(x=df["bedrooms"],y=df["sqft_lot"])
plt.xlabel("bedrooms")
plt.ylabel("sqft_lot")
plt.title("Housing")
plt.show()

# %%
plt.figure(figsize=(7,7))
df["bedrooms"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Housing")
plt.show()

# %%
plt.figure(figsize=(7,7))
df["bathrooms"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Housing")
plt.show()
